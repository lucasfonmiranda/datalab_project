# %%
#Import all librarys that we need to 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %%
sns.countplot("Class", data=df)

# %%
#After check the data we see the data is imbalanced

# %%
normal_transactions = len(df[df["Class"]==0]) # Normal transactions are represented by 0

fraud_transactions = len(df[df["Class"] == 1]) # Fraud transactions are represented by 1

# %%
percent_normal_transactions = normal_transactions / (normal_transactions+fraud_transactions)
print("Percent of normal transactions {}".format(percent_normal_transactions*100))
# Out:
# Percent of normal transactions 99.82725143693798

# %%
percent_fraud_transactions = fraud_transactions / (normal_transactions+fraud_transactions)
print("Percent of fraud transactions {}".format(percent_fraud_transactions*100))
# Out:
# Percent of fraud transactions 0.1727485630620034

# %%
# With this data we can check we have 0.17% of fraud transactions and 99.82% of valid transactions

# %%
Normal_transactions = df[df["Class"] == 0] #Normal transactions
Fraud_transactions = df[df["Class"] == 1] #fraud transactions

plt.figure(figsize=(10,6))
plt.subplot(121)

Fraud_transactions.Amount.plot.hist(title="Fraud Transactions")

plt.subplot(122)

Normal_transactions.Amount.plot.hist(title="Normal Transactions")

# %%
Normal_transactions = df[df["Class"] == 0] #Normal transactions
Fraud_transactions = df[df["Class"] == 1] #fraud transactions

plt.figure(figsize=(10,6))
plt.subplot(121)

Fraud_transactions[Fraud_transactions["Amount"]<= 2500].Amount.plot.hist(title="Fraud Transactions")

plt.subplot(122)

Normal_transactions[Normal_transactions["Amount"] <= 2500].Amount.plot.hist(title="Normal Transactions")

# %%
# lets us see the index of fraud cases

fraud_indices = np.array(df[df.Class==1].index)
normal_indices = np.array(df[df.Class==0].index)

# let us a define a function for make undersample dara with different proportion

def undersample(normal_indices, fraud_indices, times):
    
    Normal_indices_undersample = np.array(np.random.choice(normal_indices, (times * Fraud_transactions), replace=False))
    undersample_data = np.concatenate([fraud_indices, Normal_indices_undersample])
    undersample_data = data.iloc[undersample_data]
    
    print("the normal transacation proportion is :",len(undersample_data[undersample_data.Class==0])/len(undersample_data[undersample_data.Class]))
    print("the fraud transacation proportion is :",len(undersample_data[undersample_data.Class==1])/len(undersample_data[undersample_data.Class]))
    print("total number of record in resampled data is:",len(undersample_data[undersample_data.Class]))
    return(undersample_data)
